# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshanshres/numpy/blob/main/18_Dataframe_Methos_vvop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
marks = pd.DataFrame([
    [100,300,4600, 10],
    [120,345,664,642],
    [200, 300, 400, 500]],
    columns = ['iq', 'marks', 'package', 'fees']
)
marks
# Out:
#     iq  marks  package  fees
# 0  100    300     4600    10
# 1  120    345      664   642
# 2  200    300      400   500

# %%
#value_coutn
marks.value_counts()
# Out:
# iq   marks  package  fees
# 100  300    4600     10      1
# 120  345    664      642     1
# 200  300    400      500     1
# dtype: int64

# %%
#find which players has won must player of the match in finals and qualifiers.
ipl = pd.read_csv("ipl-matches.csv")
ipl['MatchNumber']
# Out:
# 0            Final
# 1      Qualifier 2
# 2       Eliminator
# 3      Qualifier 1
# 4               70
#           ...
# 945              4
# 946              5
# 947              3
# 948              2
# 949              1
# Name: MatchNumber, Length: 950, dtype: object

# %%
ipl['MatchNumber'].str.isdigit()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 945     True
# 946     True
# 947     True
# 948     True
# 949     True
# Name: MatchNumber, Length: 950, dtype: bool

# %%
#for opposite garna ko lag
~ipl['MatchNumber'].str.isdigit()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
# POTM
ipl[~ipl['MatchNumber'].str.isdigit()]
# Out:
#           ID           City        Date   Season         MatchNumber  \
# 0    1312200      Ahmedabad  2022-05-29     2022               Final
# 1    1312199      Ahmedabad  2022-05-27     2022         Qualifier 2
# 2    1312198        Kolkata  2022-05-25     2022          Eliminator
# 3    1312197        Kolkata  2022-05-24     2022         Qualifier 1
# 74   1254117          Dubai  2021-10-15     2021               Final
# 75   1254116        Sharjah  2021-10-13     2021         Qualifier 2
# 76   1254115        Sharjah  2021-10-11     2021          Eliminator
# 77   1254114          Dubai  2021-10-10     2021         Qualifier 1
# 134  1237181            NaN  2020-11-10  2020/21               Final
# 135  1237180      Abu Dhabi  2020-11-08  2020/21         Qualifier 2
# 136  1237178      Abu Dhabi  2020-11-06  2020/21          Eliminator
# 137  1237177            NaN  2020-11-05  2020/21         Qualifier 1
# 194  1181768      Hyderabad  2019-05-12     2019               Final
# ...

# %%
# POTM
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0              HH Pandya
# 1             JC Buttler
# 2             RM Patidar
# 3              DA Miller
# 74          F du Plessis
# 75               VR Iyer
# 76             SP Narine
# 77            RD Gaikwad
# 134             TA Boult
# 135           MP Stoinis
# 136        KS Williamson
# 137            JJ Bumrah
# 194            JJ Bumrah
# 195         F du Plessis
# 196              RR Pant
# 197             SA Yadav
# 254            SR Watson
# 255          Rashid Khan
# 256           AD Russell
# 257         F du Plessis
# 314            KH Pandya
# 315            KV Sharma
# 316      NM Coulter-Nile
# 317    Washington Sundar
# 373          BCJ Cutting
# 374            DA Warner
# 375         MC Henriques
# 376       AB de Villiers
# 433            RG Sharma
# 434              A Nehra
# 435       AB de Villiers
# 436           KA Pollard
# 492            MK Pandey
# 493             V Sehwag
# 494             SK Raina
# ...

# %%
#Q. Toss decission [head or tail]
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl['TossDecision'].value_counts()
# Out:
# field    599
# bat      351
# Name: TossDecision, dtype: int64

# %%
#plot in the series
ipl['TossDecision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='TossDecision'>
